# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv("pizza sales.csv")

# %%
df.head()
# Out:
#    order_details_id  order_id       pizza_id  quantity order_date order_time  \
# 0                 1         1     hawaiian_m         1   1/1/2015   11:38:36
# 1                 2         2  classic_dlx_m         1   1/1/2015   11:57:40
# 2                 3         2  five_cheese_l         1   1/1/2015   11:57:40
# 3                 4         2    ital_supr_l         1   1/1/2015   11:57:40
# 4                 5         2     mexicana_m         1   1/1/2015   11:57:40
#
#    unit_price  total_price pizza_size pizza_category  \
# 0       13.25        13.25          M        Classic
# 1       16.00        16.00          M        Classic
# 2       18.50        18.50          L         Veggie
# 3       20.75        20.75          L        Supreme
# 4       16.00        16.00          M         Veggie
#
#                                    pizza_ingredients  \
# 0           Sliced Ham, Pineapple, Mozzarella Cheese
# 1  Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# 2  Mozzarella Cheese, Provolone Cheese, Smoked Go...
# 3  Calabrese Salami, Capocollo, Tomatoes, Red Oni...
# 4  Tomatoes, Red Peppers, Jalapeno Peppers, Red O...
#
#                   pizza_name
# 0         The Hawaiian Pizza
# 1   The Classic Deluxe Pizza
# 2      The Five Cheese Pizza
# 3  The Italian Supreme Pizza
# 4         The Mexicana Pizza

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   order_details_id   48620 non-null  int64
#  1   order_id           48620 non-null  int64
#  2   pizza_id           48620 non-null  object
#  3   quantity           48620 non-null  int64
#  4   order_date         48620 non-null  object
#  5   order_time         48620 non-null  object
#  6   unit_price         48620 non-null  float64
#  7   total_price        48620 non-null  float64
#  8   pizza_size         48620 non-null  object
#  9   pizza_category     48620 non-null  object
#  10  pizza_ingredients  48620 non-null  object
#  11  pizza_name         48620 non-null  object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 4.5+ MB

# %%
df.sample(5)
# Out:
#        order_details_id  order_id       pizza_id  quantity  order_date  \
# 48445             48446     21275      bbq_ckn_l         1  12/30/2015
# 35544             35545     15691  ital_cpcllo_m         1   9/19/2015
# 28467             28468     12541     hawaiian_s         1   7/28/2015
# 1468               1469       651    pepperoni_m         1   1/11/2015
# 9705               9706      4251  ital_veggie_s         1   3/13/2015
#
#       order_time  unit_price  total_price pizza_size pizza_category  \
# 48445   20:12:27       20.75        20.75          L        Chicken
# 35544   17:48:05       16.00        16.00          M        Classic
# 28467   19:09:15       10.50        10.50          S        Classic
# 1468    14:49:35       12.50        12.50          M        Classic
# 9705    15:27:34       12.75        12.75          S         Veggie
#
#                                        pizza_ingredients  \
# 48445  Barbecued Chicken, Red Peppers, Green Peppers,...
# 35544  Capocollo, Red Peppers, Tomatoes, Goat Cheese,...
# 28467           Sliced Ham, Pineapple, Mozzarella Cheese
# 1468                        Mozzarella Cheese, Pepperoni
# 9705   Eggplant, Artichokes, Tomatoes, Zucchini, Red ...
#
#                          pizza_name
# 48445    The Barbecue Chicken Pizza
# 35544   The Italian Capocollo Pizza
# 28467            The Hawaiian Pizza
# 1468            The Pepperoni Pizza
# 9705   The Italian Vegetables Pizza

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Missing Values

# %%
df.isna().sum()
# Out:
# order_details_id     0
# order_id             0
# pizza_id             0
# quantity             0
# order_date           0
# order_time           0
# unit_price           0
# total_price          0
# pizza_size           0
# pizza_category       0
# pizza_ingredients    0
# pizza_name           0
# dtype: int64

# %%
df.describe(include='all')
# Out:
#         order_details_id      order_id    pizza_id      quantity  order_date  \
# count       48620.000000  48620.000000       48620  48620.000000       48620
# unique               NaN           NaN          91           NaN         358
# top                  NaN           NaN  big_meat_s           NaN  11/26/2015
# freq                 NaN           NaN        1811           NaN         261
# mean        24310.500000  10701.479761         NaN      1.019622         NaN
# std         14035.529381   6180.119770         NaN      0.143077         NaN
# min             1.000000      1.000000         NaN      1.000000         NaN
# 25%         12155.750000   5337.000000         NaN      1.000000         NaN
# 50%         24310.500000  10682.500000         NaN      1.000000         NaN
# 75%         36465.250000  16100.000000         NaN      1.000000         NaN
# max         48620.000000  21350.000000         NaN      4.000000         NaN
#
#        order_time    unit_price   total_price pizza_size pizza_category  \
# count       48620  48620.000000  48620.000000      48620          48620
# unique      16382           NaN           NaN          5              4
# top      12:32:00           NaN           NaN          L        Classic
# freq           26           NaN           NaN      18526          14579
# mean          NaN     16.494132     16.821474        NaN            NaN
# std           NaN      3.621789      4.437398        NaN            NaN
# min           NaN      9.750000      9.750000        NaN            NaN
# 25%           NaN     12.750000     12.750000        NaN            NaN
# 50%           NaN     16.500000     16.500000        NaN            NaN
# 75%           NaN     20.250000     20.500000        NaN            NaN
# max           NaN     35.950000     83.000000        NaN            NaN
#
#                                         pizza_ingredients  \
# count                                               48620
# unique                                                 32
# top     Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# freq                                                 2416
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                       pizza_name
# count                      48620
# unique                        32
# top     The Classic Deluxe Pizza
# freq                        2416
# mean                         NaN
# std                          NaN
# min                          NaN
# 25%                          NaN
# 50%                          NaN
# 75%                          NaN
# max                          NaN

# %%
print("The length of the dataset is", df.shape)
# Out:
# The length of the dataset is (48620, 12)

# %%
df['order_time'].apply(lambda x:str(x))
# Out:
# 0        11:38:36
# 1        11:57:40
# 2        11:57:40
# 3        11:57:40
# 4        11:57:40
#            ...
# 48615    21:23:10
# 48616    21:23:10
# 48617    21:23:10
# 48618    22:09:54
# 48619    23:02:05
# Name: order_time, Length: 48620, dtype: object

# %%
df['order_time'].apply(lambda x:type(x))
# Out:
# 0        <class 'str'>
# 1        <class 'str'>
# 2        <class 'str'>
# 3        <class 'str'>
# 4        <class 'str'>
#              ...
# 48615    <class 'str'>
# 48616    <class 'str'>
# 48617    <class 'str'>
# 48618    <class 'str'>
# 48619    <class 'str'>
# Name: order_time, Length: 48620, dtype: object

# %%
date=[]
for i in df['order_date'].apply(lambda x:str(x)).str.split(' '):
    date.append(i[0])

# %%
df['order_date']=pd.Series(date) 
df.head()
# Out:
#    order_details_id  order_id       pizza_id  quantity order_date order_time  \
# 0                 1         1     hawaiian_m         1   1/1/2015   11:38:36
# 1                 2         2  classic_dlx_m         1   1/1/2015   11:57:40
# 2                 3         2  five_cheese_l         1   1/1/2015   11:57:40
# 3                 4         2    ital_supr_l         1   1/1/2015   11:57:40
# 4                 5         2     mexicana_m         1   1/1/2015   11:57:40
#
#    unit_price  total_price pizza_size pizza_category  \
# 0       13.25        13.25          M        Classic
# 1       16.00        16.00          M        Classic
# 2       18.50        18.50          L         Veggie
# 3       20.75        20.75          L        Supreme
# 4       16.00        16.00          M         Veggie
#
#                                    pizza_ingredients  \
# 0           Sliced Ham, Pineapple, Mozzarella Cheese
# 1  Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# 2  Mozzarella Cheese, Provolone Cheese, Smoked Go...
# 3  Calabrese Salami, Capocollo, Tomatoes, Red Oni...
# 4  Tomatoes, Red Peppers, Jalapeno Peppers, Red O...
#
#                   pizza_name
# 0         The Hawaiian Pizza
# 1   The Classic Deluxe Pizza
# 2      The Five Cheese Pizza
# 3  The Italian Supreme Pizza
# 4         The Mexicana Pizza

# %%
df['order_time']=df['order_time'].astype('object')
df.head()
# Out:
#    order_details_id  order_id       pizza_id  quantity order_date order_time  \
# 0                 1         1     hawaiian_m         1   1/1/2015   11:38:36
# 1                 2         2  classic_dlx_m         1   1/1/2015   11:57:40
# 2                 3         2  five_cheese_l         1   1/1/2015   11:57:40
# 3                 4         2    ital_supr_l         1   1/1/2015   11:57:40
# 4                 5         2     mexicana_m         1   1/1/2015   11:57:40
#
#    unit_price  total_price pizza_size pizza_category  \
# 0       13.25        13.25          M        Classic
# 1       16.00        16.00          M        Classic
# 2       18.50        18.50          L         Veggie
# 3       20.75        20.75          L        Supreme
# 4       16.00        16.00          M         Veggie
#
#                                    pizza_ingredients  \
# 0           Sliced Ham, Pineapple, Mozzarella Cheese
# 1  Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# 2  Mozzarella Cheese, Provolone Cheese, Smoked Go...
# 3  Calabrese Salami, Capocollo, Tomatoes, Red Oni...
# 4  Tomatoes, Red Peppers, Jalapeno Peppers, Red O...
#
#                   pizza_name
# 0         The Hawaiian Pizza
# 1   The Classic Deluxe Pizza
# 2      The Five Cheese Pizza
# 3  The Italian Supreme Pizza
# 4         The Mexicana Pizza

# %%
df['order_time']=df['order_time'].apply(lambda x:str(x))

# %%
df['timestamp']=df['order_date'] + ' ' + df['order_time']
df.head()
# Out:
#    order_details_id  order_id       pizza_id  quantity order_date order_time  \
# 0                 1         1     hawaiian_m         1   1/1/2015   11:38:36
# 1                 2         2  classic_dlx_m         1   1/1/2015   11:57:40
# 2                 3         2  five_cheese_l         1   1/1/2015   11:57:40
# 3                 4         2    ital_supr_l         1   1/1/2015   11:57:40
# 4                 5         2     mexicana_m         1   1/1/2015   11:57:40
#
#    unit_price  total_price pizza_size pizza_category  \
# 0       13.25        13.25          M        Classic
# 1       16.00        16.00          M        Classic
# 2       18.50        18.50          L         Veggie
# 3       20.75        20.75          L        Supreme
# 4       16.00        16.00          M         Veggie
#
#                                    pizza_ingredients  \
# 0           Sliced Ham, Pineapple, Mozzarella Cheese
# 1  Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# 2  Mozzarella Cheese, Provolone Cheese, Smoked Go...
# 3  Calabrese Salami, Capocollo, Tomatoes, Red Oni...
# 4  Tomatoes, Red Peppers, Jalapeno Peppers, Red O...
#
#                   pizza_name          timestamp
# 0         The Hawaiian Pizza  1/1/2015 11:38:36
# 1   The Classic Deluxe Pizza  1/1/2015 11:57:40
# 2      The Five Cheese Pizza  1/1/2015 11:57:40
# 3  The Italian Supreme Pizza  1/1/2015 11:57:40
# 4         The Mexicana Pizza  1/1/2015 11:57:40

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])
df.head()
# Out:
#    order_details_id  order_id       pizza_id  quantity order_date order_time  \
# 0                 1         1     hawaiian_m         1   1/1/2015   11:38:36
# 1                 2         2  classic_dlx_m         1   1/1/2015   11:57:40
# 2                 3         2  five_cheese_l         1   1/1/2015   11:57:40
# 3                 4         2    ital_supr_l         1   1/1/2015   11:57:40
# 4                 5         2     mexicana_m         1   1/1/2015   11:57:40
#
#    unit_price  total_price pizza_size pizza_category  \
# 0       13.25        13.25          M        Classic
# 1       16.00        16.00          M        Classic
# 2       18.50        18.50          L         Veggie
# 3       20.75        20.75          L        Supreme
# 4       16.00        16.00          M         Veggie
#
#                                    pizza_ingredients  \
# 0           Sliced Ham, Pineapple, Mozzarella Cheese
# 1  Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# 2  Mozzarella Cheese, Provolone Cheese, Smoked Go...
# 3  Calabrese Salami, Capocollo, Tomatoes, Red Oni...
# 4  Tomatoes, Red Peppers, Jalapeno Peppers, Red O...
#
#                   pizza_name           timestamp
# 0         The Hawaiian Pizza 2015-01-01 11:38:36
# 1   The Classic Deluxe Pizza 2015-01-01 11:57:40
# 2      The Five Cheese Pizza 2015-01-01 11:57:40
# 3  The Italian Supreme Pizza 2015-01-01 11:57:40
# 4         The Mexicana Pizza 2015-01-01 11:57:40

# %%
df = df.sort_values('timestamp')
df.head(20)
# Out:
#     order_details_id  order_id        pizza_id  quantity order_date  \
# 0                  1         1      hawaiian_m         1   1/1/2015
# 1                  2         2   classic_dlx_m         1   1/1/2015
# 2                  3         2   five_cheese_l         1   1/1/2015
# 3                  4         2     ital_supr_l         1   1/1/2015
# 4                  5         2      mexicana_m         1   1/1/2015
# 5                  6         2      thai_ckn_l         1   1/1/2015
# 6                  7         3     ital_supr_m         1   1/1/2015
# 7                  8         3    prsc_argla_l         1   1/1/2015
# 8                  9         4     ital_supr_m         1   1/1/2015
# 9                 10         5     ital_supr_m         1   1/1/2015
# 11                12         6     the_greek_s         1   1/1/2015
# 10                11         6       bbq_ckn_s         1   1/1/2015
# 12                13         7  spinach_supr_s         1   1/1/2015
# 13                14         8  spinach_supr_s         1   1/1/2015
# 22                23         9    veggie_veg_s         1   1/1/2015
# 14                15         9   classic_dlx_s         1   1/1/2015
# 15                16         9  green_garden_s         1   1/1/2015
# 16                17         9   ital_cpcllo_l         1   1/1/2015
# 17                18         9     ital_supr_l         1   1/1/2015
# 18                19         9     ital_supr_s         1   1/1/2015
#
#    order_time  unit_price  total_price pizza_size pizza_category  \
# 0    11:38:36       13.25        13.25          M        Classic
# 1    11:57:40       16.00        16.00          M        Classic
# 2    11:57:40       18.50        18.50          L         Veggie
# 3    11:57:40       20.75        20.75          L        Supreme
# 4    11:57:40       16.00        16.00          M         Veggie
# 5    11:57:40       20.75        20.75          L        Chicken
# 6    12:12:28       16.50        16.50          M        Supreme
# 7    12:12:28       20.75        20.75          L        Supreme
# 8    12:16:31       16.50        16.50          M        Supreme
# 9    12:21:30       16.50        16.50          M        Supreme
# 11   12:29:36       12.00        12.00          S        Classic
# 10   12:29:36       12.75        12.75          S        Chicken
# 12   12:50:37       12.50        12.50          S        Supreme
# 13   12:51:37       12.50        12.50          S        Supreme
# 22   12:52:01       12.00        12.00          S         Veggie
# 14   12:52:01       12.00        12.00          S        Classic
# 15   12:52:01       12.00        12.00          S         Veggie
# 16   12:52:01       20.50        20.50          L        Classic
# 17   12:52:01       20.75        20.75          L        Supreme
# 18   12:52:01       12.50        12.50          S        Supreme
#
#                                     pizza_ingredients  \
# 0            Sliced Ham, Pineapple, Mozzarella Cheese
# 1   Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# 2   Mozzarella Cheese, Provolone Cheese, Smoked Go...
# 3   Calabrese Salami, Capocollo, Tomatoes, Red Oni...
# 4   Tomatoes, Red Peppers, Jalapeno Peppers, Red O...
# 5   Chicken, Pineapple, Tomatoes, Red Peppers, Tha...
# 6   Calabrese Salami, Capocollo, Tomatoes, Red Oni...
# 7   Prosciutto di San Daniele, Arugula, Mozzarella...
# 8   Calabrese Salami, Capocollo, Tomatoes, Red Oni...
# 9   Calabrese Salami, Capocollo, Tomatoes, Red Oni...
# 11  Kalamata Olives, Feta Cheese, Tomatoes, Garlic...
# 10  Barbecued Chicken, Red Peppers, Green Peppers,...
# 12  Spinach, Red Onions, Pepperoni, Tomatoes, Arti...
# 13  Spinach, Red Onions, Pepperoni, Tomatoes, Arti...
# 22  Mushrooms, Tomatoes, Red Peppers, Green Pepper...
# 14  Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# 15  Spinach, Mushrooms, Tomatoes, Green Olives, Fe...
# 16  Capocollo, Red Peppers, Tomatoes, Goat Cheese,...
# 17  Calabrese Salami, Capocollo, Tomatoes, Red Oni...
# 18  Calabrese Salami, Capocollo, Tomatoes, Red Oni...
#
#                            pizza_name           timestamp
# 0                  The Hawaiian Pizza 2015-01-01 11:38:36
# 1            The Classic Deluxe Pizza 2015-01-01 11:57:40
# 2               The Five Cheese Pizza 2015-01-01 11:57:40
# 3           The Italian Supreme Pizza 2015-01-01 11:57:40
# 4                  The Mexicana Pizza 2015-01-01 11:57:40
# 5              The Thai Chicken Pizza 2015-01-01 11:57:40
# 6           The Italian Supreme Pizza 2015-01-01 12:12:28
# 7    The Prosciutto and Arugula Pizza 2015-01-01 12:12:28
# 8           The Italian Supreme Pizza 2015-01-01 12:16:31
# 9           The Italian Supreme Pizza 2015-01-01 12:21:30
# 11                    The Greek Pizza 2015-01-01 12:29:36
# 10         The Barbecue Chicken Pizza 2015-01-01 12:29:36
# 12          The Spinach Supreme Pizza 2015-01-01 12:50:37
# 13          The Spinach Supreme Pizza 2015-01-01 12:51:37
# 22  The Vegetables + Vegetables Pizza 2015-01-01 12:52:01
# 14           The Classic Deluxe Pizza 2015-01-01 12:52:01
# 15             The Green Garden Pizza 2015-01-01 12:52:01
# 16        The Italian Capocollo Pizza 2015-01-01 12:52:01
# 17          The Italian Supreme Pizza 2015-01-01 12:52:01
# 18          The Italian Supreme Pizza 2015-01-01 12:52:01

# %%
numeric_columns = df.select_dtypes(include= ['number'])
sns.heatmap(numeric_columns.corr(),cmap = 'YlOrRd', annot =True)
plt.show()

# %%
df2 = pd.get_dummies(df[['order_id', 'pizza_category']].set_index('order_id', drop=True))
df2 = df2.groupby(df2.index).sum()
sns.heatmap(df2.corr(), annot=True)
# Out:
# <Axes: >

# %%
df2 = pd.get_dummies(df[['order_id', 'pizza_size']].set_index('order_id', drop=True))
df2 = df2.groupby(df2.index).sum()
sns.heatmap(df2.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ##### There is a small correlation between Medium and Large pizza sizes. A discount to the Medium size pizza should be considered.

# %%
# Display the distribution of data based on the quartiles and potential outliers.
plt.figure(figsize=(8, 5))  # Set figure size
ax = sns.boxplot(data=df[numeric_columns.columns])
plt.xticks(rotation=45)  # Rotate x-axis labels if needed
plt.title('Boxplot of Numeric Columns')
plt.xlabel('Columns')
plt.ylabel('Values of each column')
plt.grid(True)

# Calculate and plot the mean
mean_values = df[numeric_columns.columns].mean().values
plt.plot(range(len(mean_values)), mean_values, marker='o', markerfacecolor='white', markersize=6, markeredgecolor='black', linestyle='', label='Mean')

plt.legend()  # Show legend for mean marker
plt.show()

# %%
# Detect outliers using IQR (Interquartile Range)
Q1 = df['total_price'].quantile(0.25)
Q3 = df['total_price'].quantile(0.75)
IQR = Q3 - Q1
outliers = df[(df['total_price'] < Q1 - 1.5 * IQR) | (df['total_price'] > Q3 + 1.5 * IQR)]

#to show all outliers
outliers
# Out:
#        order_details_id  order_id       pizza_id  quantity  order_date  \
# 183                 184        78   spicy_ital_l         3    1/2/2015
# 211                 212        91      bbq_ckn_l         2    1/2/2015
# 341                 342       144      bbq_ckn_m         3    1/3/2015
# 456                 457       193  ckn_alfredo_l         2    1/3/2015
# 611                 612       271     cali_ckn_m         2    1/5/2015
# ...                 ...       ...            ...       ...         ...
# 48396             48397     21251  four_cheese_l         2  12/30/2015
# 48417             48418     21260   prsc_argla_m         2  12/30/2015
# 48466             48467     21288  classic_dlx_m         3  12/31/2015
# 48575             48576     21331      bbq_ckn_l         2  12/31/2015
# 48601             48602     21343   spicy_ital_l         2  12/31/2015
#
#       order_time  unit_price  total_price pizza_size pizza_category  \
# 183     12:28:14       20.75        62.25          L        Supreme
# 211     15:14:43       20.75        41.50          L        Chicken
# 341     13:44:28       16.75        50.25          M        Chicken
# 456     20:55:47       20.75        41.50          L        Chicken
# 611     14:22:19       16.75        33.50          M        Chicken
# ...          ...         ...          ...        ...            ...
# 48396   12:45:20       17.95        35.90          L         Veggie
# 48417   15:45:32       16.50        33.00          M        Supreme
# 48466   13:04:18       16.00        48.00          M        Classic
# 48575   19:05:04       20.75        41.50          L        Chicken
# 48601   20:27:23       20.75        41.50          L        Supreme
#
#                                        pizza_ingredients  \
# 183    Capocollo, Tomatoes, Goat Cheese, Artichokes, ...
# 211    Barbecued Chicken, Red Peppers, Green Peppers,...
# 341    Barbecued Chicken, Red Peppers, Green Peppers,...
# 456    Chicken, Red Onions, Red Peppers, Mushrooms, A...
# 611    Chicken, Artichoke, Spinach, Garlic, Jalapeno ...
# ...                                                  ...
# 48396  Ricotta Cheese, Gorgonzola Piccante Cheese, Mo...
# 48417  Prosciutto di San Daniele, Arugula, Mozzarella...
# 48466  Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# 48575  Barbecued Chicken, Red Peppers, Green Peppers,...
# 48601  Capocollo, Tomatoes, Goat Cheese, Artichokes, ...
#
#                              pizza_name           timestamp
# 183             The Spicy Italian Pizza 2015-01-02 12:28:14
# 211          The Barbecue Chicken Pizza 2015-01-02 15:14:43
# 341          The Barbecue Chicken Pizza 2015-01-03 13:44:28
# 456           The Chicken Alfredo Pizza 2015-01-03 20:55:47
# 611        The California Chicken Pizza 2015-01-05 14:22:19
# ...                                 ...                 ...
# 48396             The Four Cheese Pizza 2015-12-30 12:45:20
# 48417  The Prosciutto and Arugula Pizza 2015-12-30 15:45:32
# 48466          The Classic Deluxe Pizza 2015-12-31 13:04:18
# 48575        The Barbecue Chicken Pizza 2015-12-31 19:05:04
# 48601           The Spicy Italian Pizza 2015-12-31 20:27:23
#
# [613 rows x 13 columns]

# %% [markdown]
# ## Total Revenue in €

# %%
total_revenue = (df['total_price']).sum()
print("Total Revenue:", total_revenue)
# Out:
# Total Revenue: 817860.05

# %% [markdown]
# ## Average Order Value in €

# %%
avg_order_value = df.groupby('order_id')['total_price'].sum().mean()
print("Average Order Value:", avg_order_value)
# Out:
# Average Order Value: 38.30726229508196

# %% [markdown]
# ## Total Pizzas Sold

# %%
total_pizzas_sold = df['quantity'].sum()
print("Total Pizzas Sold:", total_pizzas_sold)
# Out:
# Total Pizzas Sold: 49574

# %% [markdown]
# ## Total Orders

# %%
total_orders = len(df.groupby('order_id').count())
print("Total Orders:", total_orders)
# Out:
# Total Orders: 21350

# %% [markdown]
# ## Average Pizzas per Order

# %%
avg_pizzas_per_order = df['quantity'].sum() / total_orders
print("Average Pizzas per Order:", avg_pizzas_per_order)
# Out:
# Average Pizzas per Order: 2.321967213114754

# %% [markdown]
# ## Average Unit Price and Revenue by Category

# %%
category_analysis = df.groupby('pizza_category').agg(
    average_unit_price=('unit_price', 'mean'),
    revenue_per_category=('unit_price', lambda x: (x * df['quantity']).sum())
).sort_values(by='revenue_per_category', ascending=False)
print("Average Unit Price and Revenue by Category:\n", category_analysis)
# Out:
# Average Unit Price and Revenue by Category:
#                  average_unit_price  revenue_per_category
# pizza_category
# Classic                  14.797490             220053.10
# Supreme                  17.363229             208197.00
# Chicken                  17.709408             195919.50
# Veggie                   16.612639             193690.45

# %% [markdown]
# ## Revenue by Pizza Category

# %%
category_analysis['revenue_per_category'].plot(kind='bar', color='skyblue')
plt.xlabel('Pizza Category')
plt.ylabel('Revenue')
plt.title('Revenue by Pizza Category in €')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Average Unit Price and Revenue of Pizza by Size

# %%
size_analysis = df.groupby('pizza_size').agg(
    average_unit_price=('unit_price', 'mean'),
    revenue_per_size=('unit_price', lambda x: (x * df['quantity']).sum())
).sort_values(by='revenue_per_size', ascending=False)
print("Average Unit Price and Revenue by Size:\n", size_analysis)
# Out:
# Average Unit Price and Revenue by Size:
#              average_unit_price  revenue_per_size
# pizza_size
# L                    19.802553         375318.70
# M                    15.951219         249382.25
# S                    12.364328         178076.50
# XL                   25.500000          14076.00
# XXL                  35.950000           1006.60

# %% [markdown]
# ## Revenue by Pizza Size Plot

# %%
size_analysis['revenue_per_size'].plot(kind='bar', color='blue')
plt.xlabel('Pizza Size')
plt.ylabel('Revenue')
plt.title('Revenue by Pizza Size in €')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Best Selling Pizza

# %%
best_selling_pizza_analysis = df.groupby('pizza_name').agg(
    average_unit_price=('unit_price', 'mean'),
    revenue_per_pizza=('unit_price', lambda x: (x * df['quantity']).sum())
).nlargest(8, 'revenue_per_pizza')
print("Average Unit Price and Revenue of Top 8 Pizzas:\n", best_selling_pizza_analysis)
# Out:
# Average Unit Price and Revenue of Top 8 Pizzas:
#                                average_unit_price  revenue_per_pizza
# pizza_name
# The Thai Chicken Pizza                 18.286069           43434.25
# The Barbecue Chicken Pizza             17.572934           42768.00
# The California Chicken Pizza           17.448523           41409.50
# The Classic Deluxe Pizza               15.575952           38180.50
# The Spicy Italian Pizza                18.104663           34831.25
# The Southwest Chicken Pizza            18.080504           34705.75
# The Italian Supreme Pizza              17.769740           33476.75
# The Hawaiian Pizza                     13.317194           32273.25

# %% [markdown]
# Best Selling Pizzas Revenue

# %%
best_selling_pizza_analysis['revenue_per_pizza'].plot(kind='bar', color='green')
plt.xlabel('Pizza Name')
plt.ylabel('Revenue')
plt.title('Revenue by Best Selling Pizzas in €')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df['day_of_week'] = pd.to_datetime(df['order_date']).dt.strftime('%A')
day_of_week_analysis = df.groupby('day_of_week')['order_id'].count().sort_values(ascending=False)
print("Sales by Day of the Week:\n", day_of_week_analysis)
# Out:
# Sales by Day of the Week:
#  day_of_week
# Friday       8106
# Saturday     7355
# Thursday     7323
# Wednesday    6797
# Tuesday      6753
# Monday       6369
# Sunday       5917
# Name: order_id, dtype: int64

# %% [markdown]
# Sales by Day of the Week

# %%
day_of_week_analysis.plot(kind='bar', color='yellow')
plt.xlabel('Day of the Week')
plt.ylabel('Number of Orders')
plt.title('Sales by Day of the Week in €')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Bussiest Time of the Day

# %%
df['delivery_time'] = df['order_time'].astype('string').str.slice(0, 5) 
delivery_time_analysis = df.groupby('delivery_time')['order_id'].count().nlargest(30)
print("Rush Hour:\n", delivery_time_analysis)
# Out:
# Rush Hour:
#  delivery_time
# 13:04    198
# 12:39    158
# 12:56    155
# 12:30    153
# 12:29    149
# 12:53    148
# 13:02    148
# 13:27    147
# 13:33    144
# 13:13    142
# 12:20    141
# 13:10    141
# 11:57    140
# 12:40    140
# 12:52    139
# 13:09    139
# 13:03    138
# 13:05    137
# 13:24    136
# 13:21    135
# 12:18    134
# 12:38    134
# 13:07    134
# 13:15    133
# 12:22    132
# 13:26    132
# 12:54    131
# 12:24    130
# 13:35    129
# 12:42    128
# Name: order_id, dtype: int64

# %% [markdown]
# ## Bussiest Time of the Day Plot

# %%
delivery_time_analysis.plot(kind='bar', color='teal')
plt.xlabel('Bussiest Time')
plt.ylabel('Number of Orders')
plt.title('Number of Orders by Time')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Monthly Sales Analysis

# %%
monthly_sales_analysis = df.groupby(pd.to_datetime(df['order_date']).dt.strftime('%B'))['total_price'].sum()
print("Highest Revenue Months:\n", monthly_sales_analysis)
# Out:
# Highest Revenue Months:
#  order_date
# April        68736.80
# August       68278.25
# December     64701.15
# February     65159.60
# January      69793.30
# July         72557.90
# June         68230.20
# March        70397.10
# May          71402.75
# November     70395.35
# October      64027.60
# September    64180.05
# Name: total_price, dtype: float64

# %% [markdown]
# ## Montly Sales Analysis Plot

# %%
monthly_sales_analysis.plot(kind='bar', color='blue')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.title('Sales by Month')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Highest amount of sales were registered on July and lowest amount of sales in October

# %%
size_max_price = round(df.groupby("pizza_size")["unit_price"].agg(["max", "min", "mean"]).reset_index(),2)
size_max_price
# Out:
#   pizza_size    max    min   mean
# 0          L  21.00  15.25  19.80
# 1          M  16.75  12.50  15.95
# 2          S  23.65   9.75  12.36
# 3         XL  25.50  25.50  25.50
# 4        XXL  35.95  35.95  35.95

# %% [markdown]
# ## The Most Sold Pizza

# %%
favourite_pizza = df.groupby(['pizza_name', 'pizza_size'])['order_id'].count().idxmax()
print("Favourite Pizza:", favourite_pizza)
# Out:
# Favourite Pizza: ('The Big Meat Pizza', 'S')

# %% [markdown]
# ## Lowest Priced Pizza

# %%
lowest_priced_pizza = df[['pizza_name', 'unit_price']].sort_values(by='unit_price').iloc[0]
print("Lowest Priced Pizza:\n", lowest_priced_pizza)
# Out:
# Lowest Priced Pizza:
#  pizza_name    The Pepperoni Pizza
# unit_price                   9.75
# Name: 18478, dtype: object

# %% [markdown]
# ## Highest Priced Pizza

# %%
highest_priced_pizza = df[['pizza_name', 'unit_price']].sort_values(by='unit_price', ascending=False).iloc[0]
print("Highest Priced Pizza:\n", highest_priced_pizza)
# Out:
# Highest Priced Pizza:
#  pizza_name    The Greek Pizza
# unit_price              35.95
# Name: 36037, dtype: object

# %% [markdown]
# ## Number of Pizzas by Type

# %%
pizzas_per_category = df['pizza_category'].value_counts()
print("Number of Pizzas per Category:\n", pizzas_per_category)
# Out:
# Number of Pizzas per Category:
#  pizza_category
# Classic    14579
# Supreme    11777
# Veggie     11449
# Chicken    10815
# Name: count, dtype: int64

# %% [markdown]
# ## Pizza Type Distribution

# %%
pizzas_per_category.plot(kind='pie', autopct='%1.1f%%')
plt.title('Pizza Type Distribution')
plt.axis('equal')
plt.show()

# %% [markdown]
# ## Pizza Size Distribution

# %%
pizzas_per_size = df['pizza_size'].value_counts()
print("Number of Pizzas by Size:\n", pizzas_per_size)
# Out:
# Number of Pizzas by Size:
#  pizza_size
# L      18526
# M      15385
# S      14137
# XL       544
# XXL       28
# Name: count, dtype: int64

# %%
pizzas_per_size.plot(kind='pie', autopct='%1.1f%%')
plt.title('Pizza Size Distribution')
plt.axis('equal')
plt.show()
